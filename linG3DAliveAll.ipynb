# %% [markdown]
# ### Example usage of LinG3DAliveAll

# %%
# %matplotlib ipympl

from pyLinG3D import LinG3DAliveAll
from platform import python_version
print(python_version())
# Out:
# 3.8.16

# %%
# The following parameters need to be specified:
#         pathData    -- directory with input data
#         numClones   -- total number of clones in the data
#         IsGradient -- 1 to draw drug in the background, 0 not to draw
#         xmin,xmax,ymin,ymax -- dimensions of the spacial domain
#         tmin, tmax          -- dimensions of the temporal domain
#         fileStep            -- frequency of the sampled data
#         toPrint    -- 1 to save the generated figure, 0 not to save
        
# It requires the following data in the pathData/data/ directory:
#         cell_history.txt -- file with info about each cell
#         cellID_##.txt    -- cell IDs in a file with index number ##
#         cellXY_##.txt    -- cell coordinates in a file with index ##
#         drug.txt         -- concentration of a drug for background
        
# for the examples discussed in the paper use:
#         example 1: pathData='exampleB05';  numClones=9;
#         example 2: pathData='exampleB005'; numClones=147;
#         example 3: pathData='exampleExp';  numClones=10;

# %%
# exampleB05

pathData = 'exampleB05'
numClones = 9
toPrint = 1
IsGradient = 1
xmin=-100; xmax=100; ymin=xmin; ymax=xmax  # 2D domain boundaries
tmin=0; tmax=100000                        # time/iteration boundaries
fileStep = 2000

LinG3DAliveAll(pathData,numClones,IsGradient,xmin,xmax,ymin,ymax,tmin,tmax,fileStep,toPrint).linG3DAliveAll()
# Out:
# clone=0 of 9
# clone=1 of 9
# clone=2 of 9
# ... calculating
# clone=3 of 9
# ... calculating
# ... calculating
# clone=4 of 9
# clone=5 of 9
# ... calculating
# clone=6 of 9
# clone=7 of 9
# ... calculating
# clone=8 of 9
# clone=9 of 9
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# exampleB005

pathData = 'exampleB005'
numClones = 147
toPrint = 1
IsGradient = 1
xmin=-100; xmax=100; ymin=xmin; ymax=xmax  # 2D domain boundaries
tmin=0; tmax=100000                        # time/iteration boundaries
fileStep = 2000

LinG3DAliveAll(pathData,numClones,IsGradient,xmin,xmax,ymin,ymax,tmin,tmax,fileStep,toPrint).linG3DAliveAll()
# Out:
# clone=0 of 147
# clone=1 of 147
# ... calculating
# clone=2 of 147
# ... calculating
# ... calculating
# ... calculating
# ... calculating
# ... calculating
# ... calculating
# ... calculating
# clone=3 of 147
# ... calculating
# ... calculating
# ... calculating
# ... calculating
# clone=4 of 147
# ... calculating
# ... calculating
# clone=5 of 147
# ... calculating
# clone=6 of 147
# ... calculating
# clone=7 of 147
# ... calculating
# clone=8 of 147
# ... calculating
# clone=9 of 147
# ... calculating
# clone=10 of 147
# clone=11 of 147
# clone=12 of 147
# clone=13 of 147
# clone=14 of 147
# clone=15 of 147
# clone=16 of 147
# clone=17 of 147
# clone=18 of 147
# clone=19 of 147
# clone=20 of 147
# clone=21 of 147
# clone=22 of 147
# clone=23 of 147
# clone=24 of 147
# clone=25 of 147
# clone=26 of 147
# clone=27 of 147
# clone=28 of 147
# clone=29 of 147
# clone=30 of 147
# clone=31 of 147
# clone=32 of 147
# clone=33 of 147
# clone=34 of 147
# clone=35 of 147
# clone=36 of 147
# clone=37 of 147
# clone=38 of 147
# clone=39 of 147
# clone=40 of 147
# clone=41 of 147
# clone=42 of 147
# clone=43 of 147
# clone=44 of 147
# clone=45 of 147
# clone=46 of 147
# clone=47 of 147
# clone=48 of 147
# clone=49 of 147
# clone=50 of 147
# clone=51 of 147
# clone=52 of 147
# clone=53 of 147
# clone=54 of 147
# clone=55 of 147
# clone=56 of 147
# clone=57 of 147
# clone=58 of 147
# clone=59 of 147
# clone=60 of 147
# clone=61 of 147
# clone=62 of 147
# clone=63 of 147
# clone=64 of 147
# clone=65 of 147
# clone=66 of 147
# clone=67 of 147
# clone=68 of 147
# clone=69 of 147
# clone=70 of 147
# clone=71 of 147
# clone=72 of 147
# clone=73 of 147
# clone=74 of 147
# clone=75 of 147
# clone=76 of 147
# clone=77 of 147
# clone=78 of 147
# clone=79 of 147
# clone=80 of 147
# clone=81 of 147
# clone=82 of 147
# clone=83 of 147
# clone=84 of 147
# clone=85 of 147
# clone=86 of 147
# clone=87 of 147
# clone=88 of 147
# clone=89 of 147
# clone=90 of 147
# clone=91 of 147
# clone=92 of 147
# clone=93 of 147
# clone=94 of 147
# clone=95 of 147
# clone=96 of 147
# clone=97 of 147
# clone=98 of 147
# clone=99 of 147
# clone=100 of 147
# clone=101 of 147
# clone=102 of 147
# clone=103 of 147
# clone=104 of 147
# clone=105 of 147
# clone=106 of 147
# clone=107 of 147
# clone=108 of 147
# clone=109 of 147
# clone=110 of 147
# clone=111 of 147
# clone=112 of 147
# clone=113 of 147
# clone=114 of 147
# clone=115 of 147
# clone=116 of 147
# clone=117 of 147
# clone=118 of 147
# clone=119 of 147
# clone=120 of 147
# clone=121 of 147
# clone=122 of 147
# clone=123 of 147
# clone=124 of 147
# clone=125 of 147
# clone=126 of 147
# clone=127 of 147
# clone=128 of 147
# clone=129 of 147
# clone=130 of 147
# clone=131 of 147
# clone=132 of 147
# clone=133 of 147
# clone=134 of 147
# clone=135 of 147
# clone=136 of 147
# clone=137 of 147
# clone=138 of 147
# clone=139 of 147
# clone=140 of 147
# clone=141 of 147
# clone=142 of 147
# clone=143 of 147
# clone=144 of 147
# clone=145 of 147
# clone=146 of 147
# clone=147 of 147
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# exampleExp

pathData = 'exampleExp'
numClones = 10
xmin=0; xmax=1500; ymin=0; ymax=1000  # 2D domain boundaries                # for exampleExp
tmin=0; tmax=864                        # time/iteration boundaries         # for exampleExp
IsGradient = 0           # draw drug gradient in the background 1-yes; 0-no; # for exampleExp
toPrint=1                # save the final figure
fileStep = 4       # frequency of data                                   # for exampleExp 

LinG3DAliveAll(pathData,numClones,IsGradient,xmin,xmax,ymin,ymax,tmin,tmax,fileStep,toPrint).linG3DAliveAll()
# Out:
# clone=0 of 10
# clone=1 of 10
# ... calculating
# clone=2 of 10
# ... calculating
# clone=3 of 10
# ... calculating
# clone=4 of 10
# ... calculating
# clone=5 of 10
# ... calculating
# clone=6 of 10
# ... calculating
# clone=7 of 10
# ... calculating
# clone=8 of 10
# ... calculating
# clone=9 of 10
# ... calculating
# clone=10 of 10
# ... calculating
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
